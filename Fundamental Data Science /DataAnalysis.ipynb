# %% [markdown]
# ## 1. 모듈 불러오기

# %%
my_dict={'Mon':33,'Tue':19,'Wed':15}

# %%
import pandas # import 모듈명

# %%
# 모든 모듈에는 변수, 함수, 클래스 가 존재함

# %%
# 모듈명.변수. 모듈명.함수, 모듈명.클래스

# %%
pandas.Series(my_dict)
# Out:
# Mon    33
# Tue    19
# Wed    15
# dtype: int64

# %% [markdown]
# ## 2. 모듈의 내용(변수, 함수, 클래스)등을 바로 선언

# %%
# from 모듈명 import 변수,함수,클래스
from pandas import Series

# %%
Series(my_dict)
# Out:
# Mon    33
# Tue    19
# Wed    15
# dtype: int64

# %%
from pandas import *

# %%
Series(my_dict)
# Out:
# Mon    33
# Tue    19
# Wed    15
# dtype: int64

# %% [markdown]
# ## 3. 모듈명을 별명으로 선언

# %%
import pandas as pd

# %%
pd.Series(my_dict)
# Out:
# Mon    33
# Tue    19
# Wed    15
# dtype: int64

# %%
from pandas import Series as srs

# %%
srs(my_dict)
# Out:
# Mon    33
# Tue    19
# Wed    15
# dtype: int64

# %% [markdown]
# ## 4. Reading the data

# %%
import pandas as pd

# %%
# pd.read_excel('파일명',sheet_name=번호 혹은 이름,index_col='칼럼이름')
data=pd.read_excel('HR-Employee-Attrition.xlsx',sheet_name=0,index_col='EmployeeNumber')

# %%
# 경로 지정
data=pd.read_excel('C:/Users/user/Documents/HR-Employee-Attrition.xlsx',sheet_name=0,index_col='EmployeeNumber')

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.index
# Out:
# Int64Index([   1,    2,    4,    5,    7,    8,   10,   11,   12,   13,
#             ...
#             2054, 2055, 2056, 2057, 2060, 2061, 2062, 2064, 2065, 2068],
#            dtype='int64', name='EmployeeNumber', length=1470)

# %%
data.values
# Out:
# array([[41, 'Yes', 'Travel_Rarely', ..., 4, 0, 5],
#        [49, 'No', 'Travel_Frequently', ..., 7, 1, 7],
#        [37, 'Yes', 'Travel_Rarely', ..., 0, 0, 0],
#        ...,
#        [27, 'No', 'Travel_Rarely', ..., 2, 0, 3],
#        [49, 'No', 'Travel_Frequently', ..., 6, 0, 8],
#        [34, 'No', 'Travel_Rarely', ..., 3, 1, 2]], dtype=object)

# %% [markdown]
# ## 5. Selection, addition, deletion

# %%
# selecting a single column

# %%
data['Age']
# Out:
# EmployeeNumber
# 1       41
# 2       49
# 4       37
# 5       33
# 7       27
#         ..
# 2061    36
# 2062    39
# 2064    27
# 2065    49
# 2068    34
# Name: Age, Length: 1470, dtype: int64

# %%
# selecting multiple columns
data[['Age','Attrition','BusinessTravel']]
# Out:
#                 Age Attrition     BusinessTravel
# EmployeeNumber
# 1                41       Yes      Travel_Rarely
# 2                49        No  Travel_Frequently
# 4                37       Yes      Travel_Rarely
# 5                33        No  Travel_Frequently
# 7                27        No      Travel_Rarely
# ...             ...       ...                ...
# 2061             36        No  Travel_Frequently
# 2062             39        No      Travel_Rarely
# 2064             27        No      Travel_Rarely
# 2065             49        No  Travel_Frequently
# 2068             34        No      Travel_Rarely
#
# [1470 rows x 3 columns]

# %%
data.loc[1:4]
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# 4               Research & Development                 2          2
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# 1               Life Sciences              1                        2  ...
# 2               Life Sciences              1                        3  ...
# 4                       Other              1                        4  ...
#
# ...

# %%
data[0:3]
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# 4               Research & Development                 2          2
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# 1               Life Sciences              1                        2  ...
# 2               Life Sciences              1                        3  ...
# 4                       Other              1                        4  ...
#
# ...

# %%
data.iloc[0:10,0:10]
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# 8                32        No  Travel_Frequently       1005
# 10               59        No      Travel_Rarely       1324
# 11               30        No      Travel_Rarely       1358
# 12               38        No  Travel_Frequently        216
# 13               36        No      Travel_Rarely       1299
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %%
# deleting a column
data.drop('Department',axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# 칼럼추가
data['AgeInMonth']=data['Age']*12

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'AgeInMonth'],
#       dtype='object')

# %%
data['AgeInMonth'].head()
# Out:
# EmployeeNumber
# 1    492
# 2    588
# 4    444
# 5    396
# 7    324
# Name: AgeInMonth, dtype: int64

# %% [markdown]
# ## 6. 기술 통계

# %%
# 평균, 분산, 표준편차, 중위수
# 변수별로 간단한 기초 통계를 내는 방법

# %%
# 연속형 변수
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# ...

# %%
data['Age'].mean()
# Out:
# 36.923809523809524

# %%
data['Age'].std()
# Out:
# 9.135373489136734

# %%
data['Age'].min()
# Out:
# 18

# %%
data['Age'].max()
# Out:
# 60

# %%
# 범주형 변수
data['Attrition'].value_counts() # 절대 도수
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
data['Attrition'].value_counts(normalize=True) # 상대 도수
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64

# %% [markdown]
# ## 7. 필터링

# %%
data.loc[data['JobSatisfaction']==1]
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  DistanceFromHome  \
# EmployeeNumber
# 10               59        No      Travel_Rarely       1324                 3
# 20               29        No      Travel_Rarely       1389                21
# 27               36       Yes      Travel_Rarely       1218                 9
# 31               34       Yes      Travel_Rarely        699                 6
# 33               32       Yes  Travel_Frequently       1125                16
# ...             ...       ...                ...        ...               ...
# 2038             32        No      Travel_Rarely        529                 2
# 2054             29        No      Travel_Rarely        468                28
# 2055             50       Yes      Travel_Rarely        410                28
# 2057             31        No         Non-Travel        325                 5
# 2062             39        No      Travel_Rarely        613                 6
#
# ...

# %%
# 데이터 소트하기, 범주형 변수 --> 연속형으로 변환, 데이터 그루핑
# -> 탐색적 자료 분석
