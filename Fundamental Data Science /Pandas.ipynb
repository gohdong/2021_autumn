# %% [markdown]
# # Pandas library

# %%
import pandas as pd

# %% [markdown]
# ## 1. 데이터 생성하기

# %% [markdown]
# ### 1.1 Series 생성하기

# %%
s1=pd.Series([10,20,30,40,50])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s1.values
# Out:
# array([10, 20, 30, 40, 50], dtype=int64)

# %%
s2=pd.Series(['a','b','c',1,2,3])

# %%
print(s2)
# Out:
# 0    a
# 1    b
# 2    c
# 3    1
# 4    2
# 5    3
# dtype: object

# %%
# 인덱스를 직접 입력하는경우

# %%
temperature=[33,19,15,89,11,-5,9]
days=['Mon','Tues','Wed','Thurs','Fri','Sat','Sun']

# %%
series_from_list=pd.Series(temperature,days)

# %%
# dictionary를 이용한 방법

# %%
my_dict={'Mon':33,'Tues':19,'Wed':15,'Thurs':20,'Fri':30,'Sat':40,'Sun':25}

# %%
series_from_dict=pd.Series(my_dict)

# %% [markdown]
# ### 1.2 DataFrame 생성하기

# %%
print([[1,2,3],[4,5,6],[7,8,9]])
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# ### DataFrame 생성문
# pd.DataFrame(data [, index=....,columns=.....])

# %%
# numpy array를 이용한 생성
import numpy as np

# %%
data_list=np.array([[10,20,30],[40,50,60],[70,80,90]])

# %%
columns_list=['A','B','C']
index_list=[1,2,3]
pd.DataFrame(data_list,index=index_list,columns=columns_list)
# Out:
#     A   B   C
# 1  10  20  30
# 2  40  50  60
# 3  70  80  90

# %%
# dictionary를 이용한 생성

# %%
table={'연도':[2015,2016,2016,2017,2017],
      '지사':['한국','한국','미국','한국','미국'],
      '고객수':[200,259,450,300,500]}

# %%
table
# Out:
# {'연도': [2015, 2016, 2016, 2017, 2017],
#  '지사': ['한국', '한국', '미국', '한국', '미국'],
#  '고객수': [200, 259, 450, 300, 500]}

# %%
pd.DataFrame(table)
# Out:
#      연도  지사  고객수
# 0  2015  한국  200
# 1  2016  한국  259
# 2  2016  미국  450
# 3  2017  한국  300
# 4  2017  미국  500

# %% [markdown]
# ## 2. Slicing and Indexing

# %%
import pandas as pd
df=pd.read_excel('HR-Employee-Attrition.xlsx',sheet_name=0,index_col='EmployeeNumber')

# %%
df.index
# Out:
# Int64Index([   1,    2,    4,    5,    7,    8,   10,   11,   12,   13,
#             ...
#             2054, 2055, 2056, 2057, 2060, 2061, 2062, 2064, 2065, 2068],
#            dtype='int64', name='EmployeeNumber', length=1470)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.values
# Out:
# array([[41, 'Yes', 'Travel_Rarely', ..., 4, 0, 5],
#        [49, 'No', 'Travel_Frequently', ..., 7, 1, 7],
#        [37, 'Yes', 'Travel_Rarely', ..., 0, 0, 0],
#        ...,
#        [27, 'No', 'Travel_Rarely', ..., 2, 0, 3],
#        [49, 'No', 'Travel_Frequently', ..., 6, 0, 8],
#        [34, 'No', 'Travel_Rarely', ..., 3, 1, 2]], dtype=object)

# %%
df.head(10)
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# 8                32        No  Travel_Frequently       1005
# 10               59        No      Travel_Rarely       1324
# 11               30        No      Travel_Rarely       1358
# 12               38        No  Travel_Frequently        216
# 13               36        No      Travel_Rarely       1299
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %%
df.tail()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 2061            Research & Development                23          2
# 2062            Research & Development                 6          1
# 2064            Research & Development                 4          3
# 2065                             Sales                 2          3
# 2068            Research & Development                 8          3
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# ...

# %% [markdown]
# ### 2.1 slice

# %% [markdown]
# ### 행을 불러올 때
# #### DataFrame_data[행시작:행끝 위치]

# %%
df[0:2] # 데이터 프레임 데이터에서 연속된 구간의 행데이터를 선택하려면 '행시작위치'와'끝위치'를 지정한다
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# 1               Life Sciences              1                        2  ...
# 2               Life Sciences              1                        3  ...
#
#                RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# EmployeeNumber
# 1                                     1             80                 0
# 2                                     4             80                 1
#
# ...

# %%
df[0:10]
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# 8                32        No  Travel_Frequently       1005
# 10               59        No      Travel_Rarely       1324
# 11               30        No      Travel_Rarely       1358
# 12               38        No  Travel_Frequently        216
# 13               36        No      Travel_Rarely       1299
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %%
## 칼럼 정보를 이용하려면 '칼럼명'을 지정한 후에 인덱스 정보를 입력한다

# %%
df['Attrition'][0:15]
# Out:
# EmployeeNumber
# 1     Yes
# 2      No
# 4     Yes
# 5      No
# 7      No
# 8      No
# 10     No
# 11     No
# 12     No
# 13     No
# 14     No
# 15     No
# 16     No
# 18     No
# 19    Yes
# Name: Attrition, dtype: object

# %% [markdown]
# ## 인덱스 이름을 지정하고 싶은 경우

# %%
# 인덱스 이름을 이용하여 행을 선택하고 싶은 경우에는 loc[index_name]를 사용한다.
df.loc[1]
# Out:
# Age                                      41
# Attrition                               Yes
# BusinessTravel                Travel_Rarely
# DailyRate                              1102
# Department                            Sales
# DistanceFromHome                          1
# Education                                 2
# EducationField                Life Sciences
# EmployeeCount                             1
# EnvironmentSatisfaction                   2
# Gender                               Female
# HourlyRate                               94
# JobInvolvement                            3
# JobLevel                                  2
# JobRole                     Sales Executive
# JobSatisfaction                           4
# MaritalStatus                        Single
# MonthlyIncome                          5993
# MonthlyRate                           19479
# NumCompaniesWorked                        8
# Over18                                    Y
# ...

# %%
df.loc[1:10] #[시작인덱스명:끝나는 인덱스명]
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# 8                32        No  Travel_Frequently       1005
# 10               59        No      Travel_Rarely       1324
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# 4               Research & Development                 2          2
# 5               Research & Development                 3          4
# 7               Research & Development                 2          1
# ...

# %%
df['Department'].loc[1:10] # 데이터 프레임에서 칼럼명과 인덱스 명을 지정
# Out:
# EmployeeNumber
# 1                      Sales
# 2     Research & Development
# 4     Research & Development
# 5     Research & Development
# 7     Research & Development
# 8     Research & Development
# 10    Research & Development
# Name: Department, dtype: object

# %% [markdown]
# ### DataFrame_data[column_name].loc[start_index_name:end_index_name]

# %% [markdown]
# ### DataFrame_data[column_name].[start_index_position:end_index_position]
